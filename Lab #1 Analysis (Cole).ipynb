# %%
import ugradio #if remote comment this section out
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
import pandas as pd

# %%
df = pd.read_csv('test_data_012222')
x = np.arange(2048)

# %%
data_100_230 = df['fgen_100_sample_230']
plt.figure()
plt.plot(x, data_100_230)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
four_100_230 = ugradio.dft.dft(data_100_230)
plt.figure()
plt.title('Fgen_100_Sample_230 DFT')
plt.plot(four_100_230[0], four_100_230[1].real, label = 'Real')
plt.plot(four_100_230[0], four_100_230[1].imag, label = 'Imaginary')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data_100_2200 = df['fgen_100_sample_2200']
plt.figure()
plt.plot(x, data_100_2200)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
four_100_2200 = ugradio.dft.dft(data_100_2200)
plt.figure()
plt.title('Fgen_100_Sample_2200')
plt.plot(four_100_2200[0], four_100_2200[1].real, label = 'Real')
plt.plot(four_100_2200[0], four_100_2200[1].imag, label = 'Imaginary')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
